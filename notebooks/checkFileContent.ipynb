# %% [markdown]
# # Check the content of the data files
#
# For each file in `goodFiles.txt`, check the content of the file, which comprises:
# - that the date in the name of the file corresponds to that inside the file.
# - specific actions depending on the file type (see details below).

# %%
import os
import numpy as np
from datetime import datetime
import pyxdf
from openmovement.load import CwaData

import logging


# this should be set to false for production use
# and set to true for testing (default) but can be already set to false from outside (e.g., by the test script)

if "doRunTests" not in globals():
    doRunTests = True

# %% [markdown]
# # Check the content of ONE data file
#
# For one file, check that the date in the name of the file corresponds to that inside the file.

# %% [markdown]
# ### Checks for csv files

# %%
# # import the mouse and kinect csv files utilities
# # use -i to run this script in the IPython console
# run_command = "-i check_csv_files.ipynb"
# if "doRunTests" in globals():
#     if doRunTests == False:
#         get_ipython().run_line_magic("run", run_command)
#     else:
#         doRunTests = False
#         get_ipython().run_line_magic("run", run_command)
#         doRunTests = True

# if "doRunTests" not in globals():
#     doRunTests = False  # necessary to %run
#     get_ipython().run_line_magic("run", run_command)
#     del doRunTests  # remove the variable from the namespace


import sys

# add the path to the src directory to the sys.path...
sys.path.append("..")
# ... so that we can explicitly import all functions (useful for ruff)
from src.rearm.check_csv import (
    # is_lsl_mouse_csv_file,
    # is_lsl_mouse_marker_csv_file,
    # is_lsl_mouse_mocap_file,
    # is_lsl_kinect_csv_file,
    # is_lsl_kinect_mocap_file,
    # is_lsl_kinect_marker_file,
    is_lsl_mouse_or_kinect_csv_file,
    check_csv_date,
)

# %%
if doRunTests:
    fnameToTest = "../dat/ReArm.lnk/ReArm_C1P02/ReArm_C1P02_20210715_V3/ReArm_C1P02_20210715_V3_Circle/ReArm_C1P02_20210715_V3_l_m_np_c.csv"
    date, msg = check_csv_date(fnameToTest)

    print(f"Date: {date}")
    print(f"Message: {msg}")

# %% [markdown]
# ### Checks for xdf files

# %%
def load_xdf_data(fullFname):
    """
    Load the streams of a xdf file
    """
    if not fullFname.endswith(".xdf"):
        raise ValueError(f"{fullFname} is not a xdf file.")

    streams, header = pyxdf.load_xdf(
        filename=fullFname,
        synchronize_clocks=True,
        dejitter_timestamps=False,  # to get the raw timestamps to compare with the CSV
        verbose=0,  # do not log anything
    )

    return streams


def set_xdf_record_date_msg(streams, msg=""):
    """
    Check the date of a xdf file
    The date is extracted from the first column of the EuroMov Mocap Kinect stream.
    """

    # get the EuroMov-Mocap-Kinect stream
    for stream in streams:
        if stream["info"]["name"][0] == "EuroMov-Mocap-Kinect":
            break

    # if not found, return the message with the error
    if stream["info"]["name"][0] != "EuroMov-Mocap-Kinect":
        msg += "No EuroMov-Mocap-Kinect stream found.\n"
        return None, msg

    if stream["time_stamps"].size == 0:
        # no data in the stream happens with eventIDE...
        msg += "No data in the EuroMov-Mocap-Kinect stream.\n"
        return None, msg

    # NOTE: Kinect bug: sometimes a block of rows is filled with zeros
    # get the index of rows in xdf_kinect_mocap_data that are filled with zeros
    xdf_kinect_mocap_data = stream["time_series"]
    zero_rows = np.all(xdf_kinect_mocap_data == 0, axis=1)
    zero_rows_indices = np.where(zero_rows)[0]
    if zero_rows_indices.size > 0:
        msg += f"Found {zero_rows_indices.size}/{len(xdf_kinect_mocap_data)} rows filled with zeros in EuroMov-Mocap-Kinect stream.\n"
        first_non_zero_row = np.where(~zero_rows)
        if first_non_zero_row[0].size > 0:
            first_non_zero_row = first_non_zero_row[0][0]
        else:
            first_non_zero_row = "not found"
        msg += f"The first non-zero row is {first_non_zero_row}.\n"

    # we let the first sample as it is: if zero, then date is set to 1970-01-01 00:00:00
    first_sample = stream["time_series"][0]
    timestamp = first_sample[0]
    timestamp = timestamp / 1000  # convert to seconds (from milliseconds)
    date_time = datetime.fromtimestamp(timestamp, tz=None)

    msg += f"Recorded, {date_time}\n"

    return date_time, msg


def set_stream_info(
    s_name,
    s_type,
    s_channel_count,
    s_channel_format,
    s_nominal_srate,
    s_nb_samples,
    nb_sec,
    duration,
    s_hostname,
):
    """
    Format the stream info in a string
    """
    return f"{s_name:25s}, {s_type:13s}, {s_channel_count:4s}, {s_channel_format:8s}, {s_nominal_srate:6s}, {s_nb_samples:10s}, {nb_sec:6s}, {duration:8s}, {s_hostname}"


def sec_to_hms(sec):
    """
    Convert seconds to hours, minutes and seconds
    """
    hours = sec // 3600
    sec %= 3600
    minutes = sec // 60
    sec %= 60
    return hours, minutes, sec


def set_xdf_streams_info_msg(streams, msg=""):
    """
    Set the stream info in a list of stings and append them to a message
    """

    streams_info = []

    for stream in streams:
        s_name = stream["info"]["name"][0]
        s_type = stream["info"]["type"][0]
        s_channel_count = stream["info"]["channel_count"][0]
        s_channel_format = stream["info"]["channel_format"][0]
        s_nominal_srate = stream["info"]["nominal_srate"][0]
        s_hostname = stream["info"]["hostname"][0]
        s_nb_samples = stream["time_stamps"].size

        if stream["time_stamps"].size == 0:
            # no data in the stream happens with eventIDE...
            start_time = 0
            end_time = 0
            nb_sec = 0
        else:
            start_time = stream["time_stamps"][0]
            end_time = stream["time_stamps"][-1]
            nb_sec = end_time - start_time

        # convert the duration to a human readable format
        hours, minutes, seconds = sec_to_hms(nb_sec)
        duration = f"{int(hours):02d}:{int(minutes):02d}:{int(seconds):02d}"

        # convert the floats to strings for set_stream_info
        s_nominal_srate = f"{float(s_nominal_srate):.0f}"
        s_nb_samples = f"{float(s_nb_samples):.0f}"
        nb_sec = f"{nb_sec:.0f}"

        stream_info = set_stream_info(
            s_name,
            s_type,
            s_channel_count,
            s_channel_format,
            s_nominal_srate,
            s_nb_samples,
            nb_sec,
            duration,
            s_hostname,
        )
        streams_info.append(stream_info)

    # header for the msg output
    msg_header = set_stream_info(
        "Name",
        "Type",
        "Ch.",
        "Format",
        "Hz",
        "Samples",
        "Nb Sec",
        "HH:MM:SS",
        "Hostname",
    )
    msg += msg_header + "\n"
    for stream in streams_info:
        msg += stream + "\n"

    return streams_info, msg


def create_xdf_txt_file(fullFname, stream_info_msg):
    """
    Create a txt file with the streams info for a xdf file
    """
    if not fullFname.endswith(".xdf"):
        raise ValueError(f"{fullFname} is not a xdf file.")

    xdf_txt_fname = fullFname.replace(".xdf", "_xdf.csv")
    with open(xdf_txt_fname, "w") as f:
        f.write(str(stream_info_msg))

    return xdf_txt_fname


def xdf_file_to_txt(fullFname, msg=""):
    """
    Write the streams info in a txt file
    """
    streams = load_xdf_data(fullFname)
    date_time, msg = set_xdf_record_date_msg(streams, msg)
    __, msg = set_xdf_streams_info_msg(streams, msg)
    xdf_txt_file = create_xdf_txt_file(fullFname, msg)

    # done: reset the message to the file name
    xdf_txt_file_name = os.path.basename(xdf_txt_file)
    msg += f"Created: {xdf_txt_file_name}"
    return date_time, msg


if doRunTests:
    dataPath = "../dat/ReArm.lnk/ReArm_C1P02/ReArm_C1P02_20210306_V1"
    fname = "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r.xdf"
    fnameToTest = os.path.join(dataPath, fname)
    # fnameToTest = "../dat/ReArm.lnk/Fichiers de Karima Bakhti - C1P42/V3/Reaching/ReArm_C1P42_20240918_V3_r.xdf"
    fnameToTest = "../dat/ReArm.lnk/Fichiers de Karima Bakhti - C1P42/V1/Reaching/ReArm_C1P42_20240603_V1_r_old3.xdf"

    # fnameToTest = "../dat/ReArm.lnk/C1P42/V2/Circular/task-V2_Circle.xdf"

    # fnameToTest = "../dat/ReArm.lnk/DATA_Named/C1P09/V3/Reaching/C1P09_DimRit_20211130_3_r.xdf"

    msg = xdf_file_to_txt(fnameToTest)
    for line in msg[1].split("\n"):
        print(line)

# %% [markdown]
# ### Checks for cwa files

# %%
def check_cwa_date(cwa_header, fullFname, msg=""):
    """
    Check the date of a cwa file
    The date is extracted from the header of the cwa file
    """

    # get the date from the header in the cwa file
    timestamp = cwa_header["loggingEnd"]
    cwaDate = datetime.fromtimestamp(timestamp, tz=None)

    # get the date from the file name
    fname = os.path.basename(fullFname)  # with extension
    fname = os.path.splitext(os.path.basename(fullFname))[0]  # without extension

    tokens = fname.split("_")
    dateFromFname = datetime.strptime(tokens[2], "%Y%m%d")
    # number of days  between the start of the recording and the date in the file name
    delta = cwaDate - dateFromFname
    nbDays = delta.days
    if nbDays != 0:
        if nbDays > 0:
            msg += f"The recording ended {nbDays} days after the date in the file name."
        else:
            msg += (
                f"The recording ended {-nbDays} days before the date in the file name."
            )
    return cwaDate, msg


def check_cwa_sessionId(cwa_header, fullFname, msg=""):
    """
    Check the session ID of a cwa file
    The session ID is extracted from the header of the cwa file
    """

    # get the session ID from the header in the cwa file
    sessionId = cwa_header["sessionId"]
    # make it a string
    sessionId = str(sessionId)

    # get the session ID from the file name without the extension
    fname = os.path.splitext(os.path.basename(fullFname))[0]
    # get the file nam witout the extension
    tokens = fname.split("_")
    sessionIdFromFname = tokens[6]
    if sessionId != sessionIdFromFname:
        msg += f" The session ID in the file name (Session={sessionIdFromFname}) does not match the session ID in the cwa file (Session={sessionId})."
    return sessionId, msg


def check_cwa_deviceId(cwa_header, fullFname, msg=""):
    """
    Check the device ID of a cwa file
    The device ID is extracted from the header of the cwa file
    """

    # get the device ID from the header in the cwa file
    deviceId = cwa_header["deviceId"]
    # make it a string
    deviceId = str(deviceId)

    # get the device ID from the file name without the extension
    fname = os.path.splitext(os.path.basename(fullFname))[0]
    # get the file nam witout the extension
    tokens = fname.split("_")
    if len(tokens) < 8:
        msg += " The file name does not contain the device ID."
        return deviceId, msg

    deviceIdFromFname = tokens[7]
    # remove the first two characters (e.g., "17") that are not part of the device ID
    deviceIdFromFname = deviceIdFromFname[2:]
    if deviceId != deviceIdFromFname:
        msg += f" The device ID in the file name (ID={deviceIdFromFname}) does not match the device ID in the cwa file (ID={deviceId})."
    return deviceId, msg


def check_cwa_subject_id(cwa_header, fullFname, msg=""):
    # NOTE: do not use as this will raise many errors (humans wrote the metadata)
    """
    Check the subject ID of a cwa file
    The subject ID is extracted from the header of the cwa file
    """

    # get the subject ID from the header in the cwa file
    subjectId = cwa_header["metadata"]["Subject Code"]

    # get the subject ID from the file name without the extension
    fname = os.path.splitext(os.path.basename(fullFname))[0]
    # get the file nam witout the extension
    tokens = fname.split("_")
    subjectIdFromFname = tokens[1]
    if subjectId != subjectIdFromFname:
        msg += f" The subject ID in the file name (Subj={subjectIdFromFname}) does not match the subject ID in the cwa file (Subj={subjectId})."
    return subjectId, msg


def print_cwa_header(header):
    """
    Print the header of a cwa file
    """
    for key, value in header.items():
        if key == "metadata":
            print("metadata:")
            for k, v in value.items():
                print(f"  {k}: {v}")
        else:
            print(f"{key}: {value}")


def create_cwa_header_file(fullFname, msg=""):
    """
    Create a txt file with the content of the header next to the cwa file
    """

    cwa_header = read_cwa_header(fullFname)
    headerFname = fullFname.replace(".cwa", "_header.txt")
    with open(headerFname, "w") as f:
        for key, value in cwa_header.items():
            if key == "metadata":
                f.write("metadata:\n")
                for k, v in value.items():
                    f.write(f"  {k}: {v}\n")
            else:
                f.write(f"{key}: {value}\n")

    return headerFname


def read_cwa_header(fullFname):
    """
    Open a cwa file and return the header
    """
    # load the CWA file (using with statement to ensure file is closed after use)
    with CwaData(
        fullFname, include_gyro=False, include_temperature=True, verbose=False
    ) as cwa_data:
        pass

    return cwa_data.header


def check_cwa_file(fullFname, msg=""):
    """
    Run the checks on the content of a cwa file
    """

    cwa_header = read_cwa_header(fullFname)

    # we only wan the message to be updated if there is an issue
    msg = ""  # we start with nothing to report
    _, msg = check_cwa_date(cwa_header, fullFname, msg)
    _, msg = check_cwa_sessionId(cwa_header, fullFname, msg)
    _, msg = check_cwa_deviceId(cwa_header, fullFname, msg)

    return msg


if doRunTests:
    dataPath = "../dat/ReArm.lnk/ReArm_C1P02/ReArm_C1P02_20210306_V1/ReArm_C1P02_20210306_V1_Accelerometry/"
    fname = "ReArm_C1P02_20210306_V1_ac_np_101_1742991.cwa"
    fname = "ReArm_C1P02_20210306_V1_ac_p_201_1743302.cwa"
    fnameToTest = os.path.join(dataPath, fname)

    # check the file and print the message
    msg = check_cwa_file(fnameToTest)
    if msg != "":
        print(f"{msg}\n")

    # read the header and print it
    cwa_header = read_cwa_header(fnameToTest)
    print("- - cwa header :")
    print_cwa_header(cwa_header)

    # create a header file
    cwa_header_fname = create_cwa_header_file(fnameToTest)
    print("- - saved in: " + cwa_header_fname)

# %% [markdown]
# # Check the content of ALL data files
#
# For all files, check that the date in the name of the file corresponds to that inside the file.
#
# Here, I use structured code, inspired by the previous attempt, but with functions.

# %%
class FileInfo:
    def __init__(self, file_info_fullFname):
        self.file_info_fullFname = file_info_fullFname
        self.file_info = []

    def add_file_info(self, fullFname, date, msg):
        """
        Add the file info to the list
        """
        fname = os.path.basename(fullFname)
        fpath = os.path.dirname(fullFname)

        # if the file is the file_info file, we skip it
        if fname == os.path.basename(self.file_info_fullFname):
            return

        try:
            time_str = date.strftime("%Y-%m-%d %H:%M:%S")
        except AttributeError:
            time_str = "None"

        file_info = {"fpath": fpath, "fname": fname, "date": time_str, "msg": msg}

        self.file_info.append(file_info)

    def sort_and_set_delays(self):
        """
        Sort the file info by date and set the delays between files
        """
        # sort the file info by date
        self.file_info.sort(key=lambda x: x["date"])
        # set the delays between files
        for i in range(1, len(self.file_info)):
            date1 = self.file_info[i - 1]["date"]
            date2 = self.file_info[i]["date"]
            try:
                # date1 and date2 are strings
                date1 = datetime.strptime(date1, "%Y-%m-%d %H:%M:%S")
                date2 = datetime.strptime(date2, "%Y-%m-%d %H:%M:%S")
            except ValueError:
                # if the date is None, we set the delay to None
                self.file_info[i]["delay"] = "None"
                continue
            try:
                delay = date2 - date1
                delay = delay.total_seconds()
                delay = f"{delay:.0f} s"
            except TypeError:
                delay = "None"
            self.file_info[i]["delay"] = delay

    def save(self):
        """
        Save the file info in a txt file
        """

        # sort the file info by date
        # self.file_info.sort(key=lambda x: x["date"])

        self.sort_and_set_delays()
        with open(self.file_info_fullFname, "w") as f:
            f.write(
                f"{'Date inside file':20s}: {'Delay (s)':20s} {'File name [(Message) if any]'}\n"
            )
            for file_info in self.file_info:
                f.write(f"{file_info['date']:20s}: ")
                f.write(f"{file_info.get('delay', ''):20s} ")
                f.write(f"{file_info['fname']}")
                # f.write(f" ({file_info['msg']})")
                f.write("\n")

    def __str__(self):
        """
        Return the file info as a string
        """
        file_info_str = ""
        for file_info in self.file_info:
            file_info_str += f"{file_info['fname']}\n"
            file_info_str += f"  {file_info['date']}\n"
            file_info_str += f"  {file_info['msg']}\n"
            file_info_str += f"  {file_info.get('delay', '')}\n"
        return file_info_str


def check_file_content(fullFname):

    # analyse the extension of the file
    # fpath = os.path.dirname(fullFname)
    fname = os.path.basename(fullFname)
    fname, extension = os.path.splitext(fname)

    # split the file name into tokens
    tokens = fname.split("_")

    # Initialize a message for this file
    msg = ""

    # if the date in the file is not found, we set it to None
    date_in_file = None

    if extension == ".csv":
        date_in_file, msg = check_csv_date(fullFname, msg)

    if extension == ".xdf":
        date_in_file, msg = xdf_file_to_txt(fullFname, msg)

    if extension == ".cwa":
        cwa_header = read_cwa_header(fullFname)
        # save a readable copy of the header next to the cwa file
        cwa_header_fname = create_cwa_header_file(fullFname)
        msg += f" Header saved in: {os.path.basename(cwa_header_fname)}. "
        # check the content of the cwa file
        date_in_file, msg = check_cwa_date(cwa_header, fullFname, msg)
        ____, msg = check_cwa_sessionId(cwa_header, fullFname, msg)
        ____, msg = check_cwa_deviceId(cwa_header, fullFname, msg)

    if extension not in [".csv", ".xdf", ".cwa"]:
        pass
        # msg += "Cannot check inside {} files. ".format(extension)

    if date_in_file is not None:
        date_stamp = date_in_file.strftime("%Y%m%d")
        # if the date is not good, we send a date message
        if len(tokens) <= 2:
            msg += f"No date in '{fname}'."
        elif date_stamp != tokens[2]:
            msg += (
                f"({tokens[2]}) does not match date inside the file ({date_in_file})."
            )

    # finally, we log the message if not empty
    if msg != "":
        log_message(f"{fname}{extension}: {msg}", "")

    return msg, date_in_file


def log_message(file_name, msg):
    # shift_spaces is for nice output formatting in the log file
    shift_spaces = ""  # "                                   "
    message = f"{file_name} \n{shift_spaces}{msg}"
    logging.info(message)


def check_date_of_files_in_goodFiles(absVisitPath):
    """
    Check the date of all files in the goodFiles.log of a visit
    """
    # read goodFiles.log
    goodFiles = []
    goodFiles_fname = "goodFiles.log"
    full_goodFiles_fname = os.path.join(absVisitPath, goodFiles_fname)
    with open(full_goodFiles_fname, "r") as f:
        for line in f:
            relativePath = line.strip()
            fullFname = os.path.join(absVisitPath, relativePath)
            goodFiles.append(fullFname)
    # log the number of files to check
    logging.info(f"{len(goodFiles)} files to check found in {goodFiles_fname}. ")
    # check the date of each file
    for file_path in goodFiles:
        check_file_content(file_path)


def create_log_file(visitPath, log_fname="file_content.log"):
    """
    Create a log file for the content of the files in a visit
    """
    absVisitPath = os.path.abspath(visitPath)
    full_log_fname = os.path.join(absVisitPath, log_fname)

    # remove the file if it already exists
    if os.path.isfile(full_log_fname):
        os.remove(full_log_fname)

    # Create the log file
    logging.basicConfig(
        filename=full_log_fname,
        level=logging.INFO,  # log all messages
        format="%(asctime)s - %(levelname)s - %(message)s",
        force=True,  # remove previous handlers and set the new one
    )
    return full_log_fname


def check_all_goodFiles_content(visitPath, checkLog_fname="good_files_content.log"):
    """Check the content of all files in the goodFiles.log of a visit"""

    absVisitPath = os.path.abspath(visitPath)
    full_checkLog_fname = os.path.join(absVisitPath, checkLog_fname)

    # Check if the visit was already checked (log file exists)
    if os.path.isfile(full_checkLog_fname):
        print(
            "    File content verification process already done: '%s' found"
            % checkLog_fname
        )
    else:
        # Create the log file
        logging.basicConfig(
            filename=full_checkLog_fname,
            level=logging.INFO,
            format="%(asctime)s - %(levelname)s - %(message)s",
            force=True,  # remove previous handlers and set the new one
        )

        logging.info("Starting file content check process ")

        check_date_of_files_in_goodFiles(absVisitPath)

        logging.info("File content check completed")
        print("    File content check completed: see '%s' for details" % checkLog_fname)


def is_file_to_check(fullFname):
    """
    Check if a file is to be checked
    """
    # we only check csv, xdf and cwa files
    if (
        not fullFname.endswith(".csv")
        and not fullFname.endswith(".xdf")
        and not fullFname.endswith(".cwa")
    ):
        return False
    # in csv files, we only check LSL Mouse and LSL Kinect csv files
    if fullFname.endswith(".csv") and not is_lsl_mouse_or_kinect_csv_file(fullFname):
        return False
    return True


def is_already_done_check_all_files_content_in_visit(visitPath, checkLog_fname):
    """
    Check if the visit was already processed with check_all_files_content_in_visit
    """
    absVisitPath = os.path.abspath(visitPath)
    full_checkLog_fname = os.path.join(absVisitPath, checkLog_fname)
    return os.path.isfile(full_checkLog_fname)


def check_all_files_content_in_visit(visitPath):
    """
    Check the content of all files in a visit, skipping the Visuals and Scan directories
    """

    log_fname = "file_content.log"

    if is_already_done_check_all_files_content_in_visit(visitPath, log_fname):
        print(f"    Already done: '{log_fname}' found.")
        return

    create_log_file(visitPath, log_fname)
    logging.info(f"Checking all files in {visitPath}...")
    logging.info("Starting file content check process ")

    file_info_name = "file_info.txt"
    visit_file_info = FileInfo(os.path.join(visitPath, file_info_name))
    visit_file_info_xdf = FileInfo(
        os.path.join(visitPath, file_info_name.replace(".txt", "_xdf.txt"))
    )
    for dir_in_visit in os.scandir(visitPath):
        if dir_in_visit.is_dir():
            # if visitDirectory contains Visuals, we skip it
            if "Visuals" in dir_in_visit.name or "Scan" in dir_in_visit.name:
                continue
            print(f"    {dir_in_visit.name}")
            folder_file_info = FileInfo(
                os.path.join(dir_in_visit.path, "file_info.txt")
            )
            files = os.scandir(dir_in_visit.path)
            for file in files:
                fullFname = os.path.join(dir_in_visit.path, file.name)
                if is_file_to_check(fullFname):
                    print(f"      {file.name}")
                    msg, date = check_file_content(fullFname)
                    folder_file_info.add_file_info(fullFname, date, msg)
                    visit_file_info.add_file_info(fullFname, date, msg)
                    if fullFname.endswith(".xdf"):
                        visit_file_info_xdf.add_file_info(fullFname, date, msg)
            folder_file_info.save()

    visit_file_info.save()
    visit_file_info_xdf.save()
    logging.info("File content check completed")


def remove_log_file(visitPath, log_fname="file_content.log"):
    """
    Remove the log file for the content of the files in a visit
    """
    absVisitPath = os.path.abspath(visitPath)
    full_log_fname = os.path.join(absVisitPath, log_fname)

    # Check if the visit was already checked (log file exists)
    if os.path.isfile(full_log_fname):
        os.remove(full_log_fname)
        print(f"    Removed log file: '{log_fname}'")
    else:
        print(f"    No log file to remove: '{log_fname}' not found")


if doRunTests:
    visitDirectory = "../dat/ReArm.lnk/ReArm_C1P02/ReArm_C1P02_20210306_V1"
    # visitDirectory = "../dat/ReArm.lnk/ReArm_C1P02/ReArm_C1P02_20210419_V2"
    # visitDirectory = "../dat/ReArm.lnk/ReArm_C1P02/ReArm_C1P02_20210715_V3"

    # visitDirectory = "../dat/ReArm.lnk/ReArm_C1P07/ReArm_C1P07_20210716_V1"
    #    visitDirectory = "../dat/ReArm.lnk/ReArm_C1P07/ReArm_C1P07_20210820_V2"
    # visitDirectory = "../dat/ReArm.lnk/ReArm_C1P07/ReArm_C1P07_20211116_V3"

    visitDirectory = "../dat/ReArm.lnk/C1P42/V1"
    visitDirectory = "../dat/ReArm.lnk/C1P42/V2"
    # visitDirectory = "../dat/ReArm.lnk/C1P42/V3"

    visitDirectory = "../dat/ReArm.lnk/DATA_named/C1P20/V2"
    # visitDirectory = "../dat/ReArm.lnk/DATA_named/C1P02/V2"

    log_fname = "file_content.log"
    remove_log_file(visitDirectory, log_fname=log_fname)
    check_all_files_content_in_visit(visitDirectory)
