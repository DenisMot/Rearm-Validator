# %% [markdown]
# This notebook runs a collection of tests for the notebook "kinect-to-mouse-time-correction.2.0.0.ipynb"
#
# ## Usage :
# - click on "Run All" button to run all the cells.
# - check if any error occurs.

# %%
# set the flag to NOT run the tests within the notebook
doRunTests = False

# run the outside notebooks (to get the functions)
# %run -i "kinect-to-mouse-time-correction.2.0.0.ipynb"

# %%
goodFiles = [
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r_k_m.csv",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r_k.csv",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r_l_m_mau_p.csv",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r_l_m_sau_p.csv",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r_l_m_sau_np.csv",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r_l_m_mau_np.csv",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r.easy",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r.oxy4",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r.xdf",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_k.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_k_m.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_l_m_np.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_l_m_p.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_l_np.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_l_p.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c.easy",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c.oxy4",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c.xdf",
    "ReArm_C1P02_20210306_V1_Accelerometry/ReArm_C1P02_20210306_V1_ac_p_201_1743302.cwa",
    "ReArm_C1P02_20210306_V1_Accelerometry/ReArm_C1P02_20210306_V1_ac_np_101_1742991.cwa",
]

# test of set_goodFiles(visit_path)
visit_path = "../dat/ReArm.lnk/ReArm_C1P02/ReArm_C1P02_20210306_V1"
goodFiles_from_file = load_goodFiles(visit_path)

assert len(goodFiles) == len(
    goodFiles_from_file
), f"len(goodFiles)={len(goodFiles)} != len(goodFiles_from_file)={len(goodFiles_from_file)}"

for file in goodFiles:
    assert file in goodFiles_from_file, f"file {file} not in goodFiles_from_file"

for file in goodFiles_from_file:
    assert file in goodFiles, f"file {file} not in goodFiles"

print("Test passed")

# in case of an error, re-generate the goodFiles.log file by running the notebook "checkFilesInVisit.ipynb" and then re-run this test

# %%
goodFiles = [
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r_k_m.csv",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r_k.csv",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r_l_m_mau_p.csv",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r_l_m_sau_p.csv",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r.easy",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r.oxy4",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r.xdf",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_k.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_k_m.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_l_m_np.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_l_m_p.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_l_np.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_l_p.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c.easy",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c.oxy4",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c.xdf",
    "ReArm_C1P02_20210306_V1_Accelerometry/ReArm_C1P02_20210306_V1_ac_p_201_1743302.cwa",
    "ReArm_C1P02_20210306_V1_Accelerometry/ReArm_C1P02_20210306_V1_ac_np_101_1742991.cwa",
]
xdf_csv_files = get_xdf_and_corresponding_csv_files_in_visit(goodFiles)
mandatory_files_error = check_mandatory_files(xdf_csv_files)

assert mandatory_files_error == ""

print("Test passed")

# %%
goodFiles = [
    #    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r_k_m.csv",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r_k.csv",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r_l_m_mau_p.csv",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r_l_m_sau_p.csv",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r.easy",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r.oxy4",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r.xdf",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_k.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_k_m.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_l_m_np.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_l_m_p.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_l_np.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_l_p.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c.easy",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c.oxy4",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c.xdf",
    "ReArm_C1P02_20210306_V1_Accelerometry/ReArm_C1P02_20210306_V1_ac_p_201_1743302.cwa",
    "ReArm_C1P02_20210306_V1_Accelerometry/ReArm_C1P02_20210306_V1_ac_np_101_1742991.cwa",
]
xdf_csv_files = get_xdf_and_corresponding_csv_files_in_visit(goodFiles)
mandatory_files_error = check_mandatory_files(xdf_csv_files)
print(mandatory_files_error)

assert (
    mandatory_files_error
    == "Mandatory file *_r_k_m.csv not found for ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r.xdf\n"
)

print("Test passed")

# %%
goodFiles = [
    #    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r_k_m.csv",
    #    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r_k.csv",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r_l_m_mau_p.csv",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r_l_m_sau_p.csv",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r.easy",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r.oxy4",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r.xdf",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_k.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_k_m.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_l_m_np.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_l_m_p.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_l_np.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_l_p.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c.easy",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c.oxy4",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c.xdf",
    "ReArm_C1P02_20210306_V1_Accelerometry/ReArm_C1P02_20210306_V1_ac_p_201_1743302.cwa",
    "ReArm_C1P02_20210306_V1_Accelerometry/ReArm_C1P02_20210306_V1_ac_np_101_1742991.cwa",
]
xdf_csv_files = get_xdf_and_corresponding_csv_files_in_visit(goodFiles)
mandatory_files_error = check_mandatory_files(xdf_csv_files)
print(mandatory_files_error)

assert (
    mandatory_files_error
    == "Mandatory file *_r_k.csv not found for ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r.xdf\n"
    + "Mandatory file *_r_k_m.csv not found for ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r.xdf\n"
)

print("Test passed")

# %%
goodFiles = [
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r_k_m.csv",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r_k.csv",
    #    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r_l_m_mau_p.csv",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r_l_m_sau_p.csv",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r.easy",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r.oxy4",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r.xdf",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_k.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_k_m.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_l_m_np.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_l_m_p.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_l_np.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_l_p.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c.easy",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c.oxy4",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c.xdf",
    "ReArm_C1P02_20210306_V1_Accelerometry/ReArm_C1P02_20210306_V1_ac_p_201_1743302.cwa",
    "ReArm_C1P02_20210306_V1_Accelerometry/ReArm_C1P02_20210306_V1_ac_np_101_1742991.cwa",
]
xdf_csv_files = get_xdf_and_corresponding_csv_files_in_visit(goodFiles)
mandatory_files_error = check_mandatory_files(xdf_csv_files)
print(mandatory_files_error)

assert mandatory_files_error == ""
print("Test passed")

# %%
goodFiles = [
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r_k_m.csv",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r_k.csv",
    #    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r_l_m_mau_p.csv",
    #    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r_l_m_sau_p.csv",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r.easy",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r.oxy4",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r.xdf",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_k.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_k_m.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_l_m_np.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_l_m_p.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_l_np.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_l_p.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c.easy",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c.oxy4",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c.xdf",
    "ReArm_C1P02_20210306_V1_Accelerometry/ReArm_C1P02_20210306_V1_ac_p_201_1743302.cwa",
    "ReArm_C1P02_20210306_V1_Accelerometry/ReArm_C1P02_20210306_V1_ac_np_101_1742991.cwa",
]
xdf_csv_files = get_xdf_and_corresponding_csv_files_in_visit(goodFiles)
mandatory_files_error = check_mandatory_files(xdf_csv_files)
print(mandatory_files_error)

assert (
    mandatory_files_error
    == "Mandatory file *_r_l*.csv not found for ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r.xdf\n"
)
print("Test passed")

# %%
goodFiles = [
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r_k_m.csv",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r_k.csv",
    #    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r_l_m_mau_p.csv",
    #    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r_l_m_sau_p.csv",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r.easy",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r.oxy4",
    "ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r.xdf",
    #    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_k.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_k_m.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_l_m_np.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_l_m_p.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_l_np.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c_l_p.csv",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c.easy",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c.oxy4",
    "ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c.xdf",
    "ReArm_C1P02_20210306_V1_Accelerometry/ReArm_C1P02_20210306_V1_ac_p_201_1743302.cwa",
    "ReArm_C1P02_20210306_V1_Accelerometry/ReArm_C1P02_20210306_V1_ac_np_101_1742991.cwa",
]
xdf_csv_files = get_xdf_and_corresponding_csv_files_in_visit(goodFiles)
mandatory_files_error = check_mandatory_files(xdf_csv_files)
print(mandatory_files_error)

assert (
    mandatory_files_error
    == "Mandatory file *_r_l*.csv not found for ReArm_C1P02_20210306_V1_Reaching/ReArm_C1P02_20210322_V1_r.xdf\n"
    + "Mandatory file *_c_k.csv not found for ReArm_C1P02_20210306_V1_Circle/ReArm_C1P02_20210322_V1_c.xdf\n"
)
print("Test passed")
